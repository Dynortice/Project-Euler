# %% [markdown]
# # Problem 12
# ## Highly divisible triangular number
# The sequence of triangle numbers is generated by adding the natural numbers. So the $7$th triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$. The first ten terms would be:
#
# $$1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...$$
#
# Let us list the factors of the first seven triangle numbers:
#
# $$1 : 1$$
#
# $$3 : 1, 3$$
#
# $$6 : 1, 2, 3, 6$$
#
# $$10 : 1, 2, 5, 10$$
#
# $$15 : 1, 3, 5, 15$$
#
# $$21 : 1, 3, 7, 21$$
#
# $$28 : 1, 2, 4, 7, 14, 28$$
#
# We can see that $28$ is the first triangle number to have over five divisors. What is the value of the first triangle number to have over five hundred divisors?
#
# ## Solution
# We need only prime factorization to get number of divisors.

# %%
from euler.numbers import count_divisors

# %%
def compute(n: int) -> int:
    i, triangle = 1, 1
    while count_divisors(triangle) < n:
        i += 1
        triangle += i
    return triangle

# %%
compute(5)
# Out:
# 28

# %%
compute(500)
# Out:
# 76576500

# %%
# %timeit -n 100 -r 1 -p 6 compute(500)
# Out:
# 949.749 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 100 loops each)
